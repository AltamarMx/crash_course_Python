# %%
import pandas as pd

# %% [markdown]
# # Explora el archivo y localizalo

# %%
file = "../../data/temixco.csv"
df = pd.read_csv(file,index_col=0,parse_dates=True)
df
# Out:
#                         Ib   Ig     To     RH     WS     WD         P
# time
# 2018-01-01 00:00:00    NaN  NaN  18.70  36.34  1.422  316.0  87864.11
# 2018-01-01 00:10:00  0.002  0.0  18.95  35.29  1.008  283.7  87876.37
# 2018-01-01 00:20:00  0.170  0.0  18.94  35.43  1.565  326.0  87888.64
# 2018-01-01 00:30:00  0.371  0.0  18.77  35.89  2.175  354.5  87887.21
# 2018-01-01 00:40:00  0.305  0.0  18.81  36.34  1.902  348.0  87886.91
# ...                    ...  ...    ...    ...    ...    ...       ...
# 2018-12-31 23:10:00  0.125  0.0  18.51  47.29  1.715  332.2  87484.32
# 2018-12-31 23:20:00  0.000  0.0  18.26  48.02  1.703  320.5  87470.70
# 2018-12-31 23:30:00  0.044  0.0  18.39  46.84  2.887  335.7  87455.03
# 2018-12-31 23:40:00  0.170  0.0  17.99  47.85  1.528  358.8  87470.02
# 2018-12-31 23:50:00  0.003  0.0  17.75  49.65  0.598  322.3  87467.29
#
# [52560 rows x 7 columns]

# %%
df.head(3)
# Out:
#                         Ib   Ig     To     RH     WS     WD         P
# time
# 2018-01-01 00:00:00    NaN  NaN  18.70  36.34  1.422  316.0  87864.11
# 2018-01-01 00:10:00  0.002  0.0  18.95  35.29  1.008  283.7  87876.37
# 2018-01-01 00:20:00  0.170  0.0  18.94  35.43  1.565  326.0  87888.64

# %%
df.tail(3)
# Out:
#                         Ib   Ig     To     RH     WS     WD         P
# time
# 2018-12-31 23:30:00  0.044  0.0  18.39  46.84  2.887  335.7  87455.03
# 2018-12-31 23:40:00  0.170  0.0  17.99  47.85  1.528  358.8  87470.02
# 2018-12-31 23:50:00  0.003  0.0  17.75  49.65  0.598  322.3  87467.29

# %%
df.index
# Out:
# DatetimeIndex(['2018-01-01 00:00:00', '2018-01-01 00:10:00',
#                '2018-01-01 00:20:00', '2018-01-01 00:30:00',
#                '2018-01-01 00:40:00', '2018-01-01 00:50:00',
#                '2018-01-01 01:00:00', '2018-01-01 01:10:00',
#                '2018-01-01 01:20:00', '2018-01-01 01:30:00',
#                ...
#                '2018-12-31 22:20:00', '2018-12-31 22:30:00',
#                '2018-12-31 22:40:00', '2018-12-31 22:50:00',
#                '2018-12-31 23:00:00', '2018-12-31 23:10:00',
#                '2018-12-31 23:20:00', '2018-12-31 23:30:00',
#                '2018-12-31 23:40:00', '2018-12-31 23:50:00'],
#               dtype='datetime64[ns]', name='time', length=52560, freq=None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 52560 entries, 2018-01-01 00:00:00 to 2018-12-31 23:50:00
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Ib      52423 non-null  float64
#  1   Ig      52423 non-null  float64
#  2   To      52560 non-null  float64
#  3   RH      52560 non-null  float64
#  4   WS      52560 non-null  float64
#  5   WD      52560 non-null  float64
#  6   P       52560 non-null  float64
# dtypes: float64(7)
# memory usage: 3.2 MB

# %%
df.describe()
# Out:
#                  Ib            Ig            To            RH           WS  \
# count  52423.000000  52423.000000  52560.000000  52560.000000  52560.00000
# mean     236.742726    257.414344     22.838098     45.152827      1.90520
# std      327.983721    345.976954      4.443339     19.426263      1.04411
# min        0.000000      0.000000      8.160000      5.648000      0.05000
# 25%        0.001000      0.000000     19.350000     29.770000      1.18000
# 50%        0.260000      3.293000     22.670000     42.600000      1.78500
# 75%      542.300000    533.900000     26.030000     59.280000      2.46000
# max     1021.000000   1348.000000     35.870000     97.700000     14.86000
#
#                  WD             P
# count  52560.000000  52560.000000
# mean     210.734453  87591.151598
# std      109.276328    245.715965
# min        0.000000  86772.650000
# 25%      134.675000  87429.500000
# 50%      211.900000  87595.090000
# 75%      319.800000  87760.647500
# max      360.000000  88516.950000

# %%
df.columns
# Out:
# Index(['Ib', 'Ig', 'To', 'RH', 'WS', 'WD', 'P'], dtype='object')

# %%
df.dtypes # a veces no se convierten por alguna raz'on y se quedan como object
# Out:
# Ib    float64
# Ig    float64
# To    float64
# RH    float64
# WS    float64
# WD    float64
# P     float64
# dtype: object

# %%
file = "../../data/temixco.xlsx"
df = pd.read_excel(file,index_col=0,parse_dates=True,header=1,engine="openpyxl")
#  pandas 1.3.5 y openpyxl
df
# Out:
#                         Ib   Ig     To     RH     WS     WD         P
# time
# 2018-01-01 00:00:00    NaN  NaN  18.70  36.34  1.422  316.0  87864.11
# 2018-01-01 00:10:00  0.002  0.0  18.95  35.29  1.008  283.7  87876.37
# 2018-01-01 00:20:00  0.170  0.0  18.94  35.43  1.565  326.0  87888.64
# 2018-01-01 00:30:00  0.371  0.0  18.77  35.89  2.175  354.5  87887.21
# 2018-01-01 00:40:00  0.305  0.0  18.81  36.34  1.902  348.0  87886.91
# ...                    ...  ...    ...    ...    ...    ...       ...
# 2018-12-31 23:10:00  0.125  0.0  18.51  47.29  1.715  332.2  87484.32
# 2018-12-31 23:20:00  0.000  0.0  18.26  48.02  1.703  320.5  87470.70
# 2018-12-31 23:30:00  0.044  0.0  18.39  46.84  2.887  335.7  87455.03
# 2018-12-31 23:40:00  0.170  0.0  17.99  47.85  1.528  358.8  87470.02
# 2018-12-31 23:50:00  0.003  0.0  17.75  49.65  0.598  322.3  87467.29
#
# [52560 rows x 7 columns]

# %%
file = "../../data/temixco.xls"
df = pd.read_excel(file)
#  comentar que ya no se puede
df
# Out:
# ---------------------------------------------------------------------------
# CompDocError                              Traceback (most recent call last)
# <ipython-input-11-af91341d0b3f> in <module>
#       1 file = "../../data/temixco.xls"
# ----> 2 df = pd.read_excel(file)
#       3 #  comentar que ya no se puede
#       4 df
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362     if not isinstance(io, ExcelFile):
#     363         should_close = True
# --> 364         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     365     elif engine and engine != io.engine:
#     366         raise ValueError(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1231         self.storage_options = storage_options
#    1232
# -> 1233         self._reader = self._engines[engine](self._io, storage_options=storage_options)
#    1234
#    1235     def __fspath__(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/excel/_xlrd.py in __init__(self, filepath_or_buffer, storage_options)
#      23         err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      24         import_optional_dependency("xlrd", extra=err_msg)
# ---> 25         super().__init__(filepath_or_buffer, storage_options=storage_options)
#      26
#      27     @property
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/excel/_base.py in __init__(self, filepath_or_buffer, storage_options)
#     418             self.handles.handle.seek(0)
#     419             try:
# --> 420                 self.book = self.load_workbook(self.handles.handle)
#     421             except Exception:
#     422                 self.close()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/excel/_xlrd.py in load_workbook(self, filepath_or_buffer)
#      36         if hasattr(filepath_or_buffer, "read"):
#      37             data = filepath_or_buffer.read()
# ---> 38             return open_workbook(file_contents=data)
#      39         else:
#      40             return open_workbook(filepath_or_buffer)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/xlrd/__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     146
#     147     from . import book
# --> 148     bk = book.open_workbook_xls(
#     149         filename=filename,
#     150         logfile=logfile,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/xlrd/book.py in open_workbook_xls(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#      80     bk = Book()
#      81     try:
# ---> 82         bk.biff2_8_load(
#      83             filename=filename, file_contents=file_contents,
#      84             logfile=logfile, verbosity=verbosity, use_mmap=use_mmap,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/xlrd/book.py in biff2_8_load(self, filename, file_contents, logfile, verbosity, use_mmap, encoding_override, formatting_info, on_demand, ragged_rows)
#     630             self.mem = self.filestr
#     631         else:
# --> 632             cd = compdoc.CompDoc(self.filestr, logfile=self.logfile)
#     633             if USE_FANCY_CD:
#     634                 for qname in ['Workbook', 'Book']:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/xlrd/compdoc.py in __init__(self, mem, logfile, DEBUG)
#     156                         print(msg, file=logfile)
#     157                         break
# --> 158                     raise CompDocError(msg)
#     159                 elif sid < 0:
#     160                     raise CompDocError("MSAT extension: invalid sector id: %d" % sid)
#
# CompDocError: MSAT extension: accessing sector 20822 but only 20822 in file

# %%
df.sum()
# Out:
# Ib    1.241076e+07
# Ig    1.349443e+07
# To    1.200370e+06
# RH    2.373233e+06
# WS    1.001373e+05
# WD    1.107620e+07
# P     4.603791e+09
# dtype: float64

# %%
df.std()  # df.max()
# Out:
# Ib    327.983721
# Ig    345.976954
# To      4.443339
# RH     19.426263
# WS      1.044110
# WD    109.276328
# P     245.715965
# dtype: float64

# %% [markdown]
# # Visualizaci'on

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %%
df.plot(subplots=True,figsize=(20,8))
# Out:
# array([<AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>,
#        <AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>,
#        <AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>,
#        <AxesSubplot:xlabel='time'>], dtype=object)

# %%
df.Ib.plot(figsize=(20,4))
# Out:
# <AxesSubplot:xlabel='time'>

# %%
df['Ib'].plot(figsize=(20,4))
# Out:
# <AxesSubplot:xlabel='time'>

# %%
df["2018-01"].plot()
# Out:
# <ipython-input-21-b570b13653ba>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df["2018-01"].plot()
# <AxesSubplot:xlabel='time'>

# %%
df.loc["2018-01"].plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %%
df.Ig.loc["2018-01"].plot(figsize=(20,4))
# Out:
# <AxesSubplot:xlabel='time'>

# %%
df.Ig.loc["2018-03-10"].plot(figsize=(20,4))
# Out:
# <AxesSubplot:xlabel='time'>

# %%
df.Ig.loc["2018-03-9":"2018-03-11"].plot(figsize=(20,4))
# Out:
# <AxesSubplot:xlabel='time'>

# %%
df[["Ig","Ib"]].loc["2018-03-9":"2018-03-11"].plot(figsize=(20,4))
# Out:
# <AxesSubplot:xlabel='time'>

# %%
df[["Ig","Ib","To"]].loc["2018-03-9":"2018-03-11"].plot(figsize=(20,4),subplots=True)
# Out:
# array([<AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>,
#        <AxesSubplot:xlabel='time'>], dtype=object)

# %% [markdown]
# # Selecci'on de valores

# %%
df.Ig>100
# Out:
# time
# 2018-01-01 00:00:00    False
# 2018-01-01 00:10:00    False
# 2018-01-01 00:20:00    False
# 2018-01-01 00:30:00    False
# 2018-01-01 00:40:00    False
#                        ...
# 2018-12-31 23:10:00    False
# 2018-12-31 23:20:00    False
# 2018-12-31 23:30:00    False
# 2018-12-31 23:40:00    False
# 2018-12-31 23:50:00    False
# Name: Ig, Length: 52560, dtype: bool

# %%
df[df.Ig>100]
# Out:
#                         Ib     Ig     To     RH     WS     WD         P
# time
# 2018-01-01 08:10:00  257.2  108.3  17.29  39.44  2.042    8.5  88105.25
# 2018-01-01 08:20:00  318.6  141.4  17.38  40.14  1.032  356.8  88111.84
# 2018-01-01 08:30:00  375.0  176.0  17.73  38.34  1.225  354.5  88111.87
# 2018-01-01 08:40:00  424.9  212.4  18.36  35.34  0.522  305.7  88142.02
# 2018-01-01 08:50:00  460.4  243.5  19.54  34.35  0.168  227.6  88148.08
# ...                    ...    ...    ...    ...    ...    ...       ...
# 2018-12-31 17:00:00  597.6  239.7  26.33  25.19  1.795  275.9  87340.14
# 2018-12-31 17:10:00  447.0  176.3  26.06  25.86  0.603  191.6  87342.19
# 2018-12-31 17:20:00  493.6  169.6  26.18  26.23  1.667  225.5  87338.11
# 2018-12-31 17:30:00  453.5  142.1  25.92  25.43  1.390  192.3  87346.95
# 2018-12-31 17:40:00  436.5  111.2  26.00  24.15  1.540  135.5  87354.44
#
# [22212 rows x 7 columns]

# %%
df[df.Ig>100].loc["2018-03-9":"2018-03-11"].plot(figsize=(20,4),subplots=True)
# Como selecciono solo una variable
# Out:
# array([<AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>,
#        <AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>,
#        <AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>,
#        <AxesSubplot:xlabel='time'>], dtype=object)
