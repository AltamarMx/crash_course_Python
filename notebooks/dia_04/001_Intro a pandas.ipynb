# %% [markdown]
# # Introducci'on a pandas
#
# https://pandas.pydata.org/
#
# ![image.png](attachment:image.png)

# %%
pip install pandas
# Out:
# WARNING: The directory '/Users/gbv/Library/Caches/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you should use sudo's -H flag.
# WARNING: Ignoring invalid distribution -umpy (/usr/local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/usr/local/lib/python3.9/site-packages)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/site-packages (1.2.3)
# Requirement already satisfied: numpy>=1.16.5 in /Users/gbv/Library/Python/3.9/lib/python/site-packages (from pandas) (1.19.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.9/site-packages (from pandas) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.9/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# WARNING: Ignoring invalid distribution -umpy (/usr/local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/usr/local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/usr/local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/usr/local/lib/python3.9/site-packages)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pandas
# Out:
# WARNING: The directory '/Users/gbv/Library/Caches/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you should use sudo's -H flag.
# WARNING: Ignoring invalid distribution -umpy (/usr/local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/usr/local/lib/python3.9/site-packages)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/site-packages (1.2.3)
# Collecting pandas
#   Downloading pandas-1.3.5-cp39-cp39-macosx_10_9_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 1.2 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.9/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.17.3 in /Users/gbv/Library/Python/3.9/lib/python/site-packages (from pandas) (1.19.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.9/site-packages (from pandas) (2021.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# WARNING: Ignoring invalid distribution -umpy (/usr/local/lib/python3.9/site-packages)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     WARNING: Ignoring invalid distribution -umpy (/usr/local/lib/python3.9/site-packages)
#     Found existing installation: pandas 1.2.3
#     Uninstalling pandas-1.2.3:
# ERROR: Could not install packages due to an OSError: Cannot move the non-empty directory '/usr/local/lib/python3.9/site-packages/pandas-1.2.3.dist-info/': Lacking write permission to '/usr/local/lib/python3.9/site-packages/pandas-1.2.3.dist-info/'.
#
# WARNING: Ignoring invalid distribution -umpy (/usr/local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/usr/local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/usr/local/lib/python3.9/site-packages)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.2.3'

# %% [markdown]
# ![image.png](attachment:image.png)
