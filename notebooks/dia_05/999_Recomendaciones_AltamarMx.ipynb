# %% [markdown]
# ## Consejos
# 1. Revisen sus datos (tipos, visualización rápida)
# 1. Aprendan a leer la documentación
# 1. Aprendan estrategias/tecnologías que implementen a su trabajo
#     1. Command line
#     1. Vim (editor texto plano)
#     1. Linux (Unix)
#     1. Git
#     1. IDE
#     1. Por supuesto Python
# 1. Leer (twitter, medium, documentación)
# 1. Practicar
#     1. Proyecto
#     1. Renuncien a su hoja de cálculo
# 1. Redes sociales:
#     1. [Altamar en Twitter](https://twitter.com/altamar)
#     1. [AltamarMx en GitHub](https://github.com/AltamarMx)
#     1. [https://altamarmx.github.io/](https://altamarmx.github.io/)

# %% [markdown]
# ![image.png](attachment:image.png)
